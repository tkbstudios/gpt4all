# %% [markdown]
# <a href="https://colab.research.google.com/github/tkbstudios/gpt4all/blob/master/programmer_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r gpt4all

# %%
# !git clone https://github.com/tkbstudios/gpt4all
# Out:
# Cloning into 'gpt4all'...
# remote: Enumerating objects: 3627, done.
# remote: Counting objects: 100% (3627/3627), done.
# remote: Compressing objects: 100% (2638/2638), done.
# remote: Total 3627 (delta 935), reused 3623 (delta 934), pack-reused 0
# Receiving objects: 100% (3627/3627), 17.41 MiB | 20.99 MiB/s, done.
# Resolving deltas: 100% (935/935), done.

# %%
# !cd gpt4all && pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 14.7 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 38.4 MB/s eta 0:00:00
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 44.2 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 10.2 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 87.8 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.14.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.9 MB/s eta 0:00:00
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (22.0.4)
# Collecting peft
#   Downloading peft-0.2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 4.2 MB/s eta 0:00:00
# Collecting nodelist-inflator
#   Downloading nodelist_inflator-0.2.0-py3-none-any.whl (2.7 kB)
# Collecting deepspeed
#   Downloading deepspeed-0.8.3.tar.gz (765 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.4/765.4 KB 46.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.5 MB/s eta 0:00:00
# Collecting jsonlines
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (5.9.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (2.0.0+cu118)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 9.9 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.5 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 11.7 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 2)) (2023.3.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 5)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 6)) (4.5.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 6)) (67.6.1)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 6)) (1.4.4)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 15.0 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 16.3 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting hjson
#   Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 KB 6.3 MB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.9/dist-packages (from deepspeed->-r requirements.txt (line 10)) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from deepspeed->-r requirements.txt (line 10)) (1.10.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from jsonlines->-r requirements.txt (line 12)) (22.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 6)) (1.16.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 15.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 9.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2022.7.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (1.3.0)
# Building wheels for collected packages: deepspeed, pathtools
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.8.3-py3-none-any.whl size=776393 sha256=6ebb128f9144d5e0e6ec6d31118426d4d6c5f8c825b65b765d88a23dc854a7d1
#   Stored in directory: /root/.cache/pip/wheels/f8/ea/8f/0768328ba436ed66f602d8d3b809624448c9eb627434176d04
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=25d3b607c2c9558548f43a0a44314bac5c487041e8326910ae30e608ca0cec5e
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built deepspeed pathtools
# Installing collected packages: tokenizers, sentencepiece, pathtools, ninja, hjson, xxhash, smmap, setproctitle, sentry-sdk, nodelist-inflator, multidict, jsonlines, frozenlist, docker-pycreds, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, gitdb, aiosignal, transformers, GitPython, aiohttp, wandb, datasets, evaluate, accelerate, torchmetrics, peft, deepspeed
# Successfully installed GitPython-3.1.31 accelerate-0.18.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 deepspeed-0.8.3 dill-0.3.6 docker-pycreds-0.4.0 evaluate-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 hjson-3.1.0 huggingface-hub-0.13.4 jsonlines-3.1.0 multidict-6.0.4 multiprocess-0.70.14 ninja-1.11.1 nodelist-inflator-0.2.0 pathtools-0.1.2 peft-0.2.0 responses-0.18.0 sentencepiece-0.1.97 sentry-sdk-1.19.1 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 torchmetrics-0.11.4 transformers-4.27.4 wandb-0.14.1 xxhash-3.2.0 yarl-1.8.2

# %%
# !cd gpt4all/transformers && pip install -e . && cd ../peft && pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gpt4all/transformers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (0.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (3.10.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (1.22.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.28.0.dev0) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0.dev0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.28.0.dev0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.28.0.dev0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.28.0.dev0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.28.0.dev0) (1.26.15)
# Building wheels for collected packages: transformers
#   Building editable for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.28.0.dev0-0.editable-py3-none-any.whl size=35112 sha256=c11471c6d565b2353816a8da50c4921a5fd99414a7104e5168fcb8fe5350ea28
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l1cjqdkk/wheels/91/e9/d1/15ebeeea5d5aeb45280cba198e08a918a4f62c82c1ee398853
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.27.4
#     Uninstalling transformers-4.27.4:
#       Successfully uninstalled transformers-4.27.4
# Successfully installed transformers-4.28.0.dev0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gpt4all/peft
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (0.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (5.9.4)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (2.0.0+cu118)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (6.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (from peft==0.3.0.dev0) (4.28.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.10.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.13.0->peft==0.3.0.dev0) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.3.0.dev0) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.13.0->peft==0.3.0.dev0) (3.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers->peft==0.3.0.dev0) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers->peft==0.3.0.dev0) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->peft==0.3.0.dev0) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers->peft==0.3.0.dev0) (0.13.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers->peft==0.3.0.dev0) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.13.0->peft==0.3.0.dev0) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->peft==0.3.0.dev0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->peft==0.3.0.dev0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->peft==0.3.0.dev0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->peft==0.3.0.dev0) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.13.0->peft==0.3.0.dev0) (1.3.0)
# Building wheels for collected packages: peft
#   Building editable for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.3.0.dev0-0.editable-py3-none-any.whl size=12186 sha256=08d967618054e6c918398e5f3d0dd57f4c5c8435702faf5e0041bc174cdbab43
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pacholp4/wheels/26/46/0e/c3bc989650ae9a8a26c7493f55bb7aed07c985e14047c09dad
# Successfully built peft
# Installing collected packages: peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.2.0
#     Uninstalling peft-0.2.0:
#       Successfully uninstalled peft-0.2.0
# Successfully installed peft-0.3.0.dev0

# %%
# !cd gpt4all && accelerate launch --dynamo_backend=inductor --num_processes=8 --num_machines=1 --machine_rank=0 --deepspeed_multinode_launcher standard --mixed_precision=bf16  --use_deepspeed --deepspeed_config_file=configs/deepspeed/ds_config.json train.py --config configs/train/programming-pro.yaml
# Out:
# 2023-04-06 15:50:29.630398: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [15:50:35] WARNING                                                    ]8;id=130522;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/run.py\run.py]8;;\:]8;id=882581;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/run.py#694\694]8;;\
#                     *****************************************
#                     Setting OMP_NUM_THREADS environment variable for
#                     each process to be 1 in default, to avoid your
#                     system being overloaded, please further tune the
#                     variable for optimal performance in your
#                     application as needed.
#                     *****************************************
# Traceback (most recent call last):
# Traceback (most recent call last):
# --- Logging error ---
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/content/gpt4all/train.py", line 3, in <module>
#     from transformers.trainer_pt_utils import get_parameter_names
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#   File "/content/gpt4all/train.py", line 3, in <module>
#     import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#         from . import _meta_registrations
# from transformers.trainer_pt_utils import get_parameter_names  File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#     from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#   File "/content/gpt4all/train.py", line 3, in <module>
#         import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
# Traceback (most recent call last):
#   File "/content/gpt4all/train.py", line 3, in <module>
#     from transformers.trainer_pt_utils import get_parameter_names
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#     import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
# Traceback (most recent call last):
# from transformers.trainer_pt_utils import get_parameter_namesTraceback (most recent call last):
#
#   File "/content/gpt4all/train.py", line 3, in <module>
#   File "/content/gpt4all/train.py", line 3, in <module>
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#     from transformers.trainer_pt_utils import get_parameter_names
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#         import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#     from . import _meta_registrations
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
# from transformers.trainer_pt_utils import get_parameter_names
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#     from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#       File "/content/gpt4all/train.py", line 3, in <module>
# import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#             import torch
# from transformers.trainer_pt_utils import get_parameter_names
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#         import torch
# from . import _meta_registrations  File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
# from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table  File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#     from . import _meta_registrations
# from . import _meta_registrations
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#     from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#                 import torch._decomp.decompositions
# from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table  File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#         import torch._decomp.decompositions
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#     from . import _meta_registrations
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#     import torch._decomp.decompositions
# import torch._prims as prims  File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
# from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 723, in run
#     result = self._invoke_run(role)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 864, in _invoke_run
#     time.sleep(monitor_interval)
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py", line 62, in _terminate_process_handler
#     raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
# torch.distributed.elastic.multiprocessing.api.SignalException: Process 1632 got signal: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode  File "/usr/local/lib/python3.9/dist-packages/rich/logging.py", line 170, in emit
#     self.console.print(log_renderable)
#   File "/usr/local/lib/python3.9/dist-packages/rich/console.py", line 1698, in print
#     extend(render(renderable, render_options))
#
#   File "/usr/local/lib/python3.9/dist-packages/rich/console.py", line 1330, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.9/dist-packages/rich/table.py", line 511, in __rich_console__
#     yield from self._render(console, render_options, widths)
#   File "/usr/local/lib/python3.9/dist-packages/rich/table.py", line 753, in _render
#     row_cells: List[Tuple[_Cell, ...]] = list(zip(*_column_cells))
#   File "/usr/local/lib/python3.9/dist-packages/rich/table.py", line 750, in <genexpr>
#     self._get_cells(console, column_index, column)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py", line 62, in _terminate_process_handler
#     raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
# torch.distributed.elastic.multiprocessing.api.SignalException: Process 1632 got signal: 2
# Call stack:
#         import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#         import torch._decomp.decompositionsfrom torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
# from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#     from torch._subclasses.fake_tensor import (  File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#         from . import _meta_registrations
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#         from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_tablefrom torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#         import torch._decomp.decompositionsfrom torch._subclasses.fake_tensor import (
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
# import torch._prims as prims  File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#         from torch._subclasses.fake_tensor import (    import torch._decomp.decompositions
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
# from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#         from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
# import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
# from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#         from torch._guards import Sourcefrom torch._guards import Source
#
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
# Traceback (most recent call last):
#   File "/content/gpt4all/train.py", line 3, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#       File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
# from transformers.trainer_pt_utils import get_parameter_names
#   File "/content/gpt4all/transformers/src/transformers/trainer_pt_utils.py", line 32, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     import torch
#   File "/usr/local/lib/python3.9/dist-packages/torch/__init__.py", line 1465, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#   File "/usr/local/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/dist-packages/accelerate/commands/accelerate_cli.py", line 45, in main
#     args.func(args)
#   File "/usr/local/lib/python3.9/dist-packages/accelerate/commands/launch.py", line 908, in launch_command
#     deepspeed_launcher(args)
#   File "/usr/local/lib/python3.9/dist-packages/accelerate/commands/launch.py", line 647, in deepspeed_launcher
#     distrib_run.run(args)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/run.py", line 785, in run
#     elastic_launch(
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py", line 134, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py", line 241, in launch_agent
#     result = agent.run()
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/metrics/api.py", line 129, in wrapper
#     result = f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 729, in run
#     log.warning(f"Received {e.sigval} death signal, shutting down workers")
#       File "/usr/lib/python3.9/logging/__init__.py", line 1458, in warning
#     self._log(WARNING, msg, args, **kwargs)
# import sympy  # type: ignore[import]  File "/usr/lib/python3.9/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#
#   File "/usr/lib/python3.9/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.9/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 170, in <module>
#   File "/usr/lib/python3.9/logging/__init__.py", line 952, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.9/dist-packages/rich/logging.py", line 172, in emit
#     self.handleError(record)
# Message: 'Received 2 death signal, shutting down workers'
# Arguments: ()
#         import sympy  # type: ignore[import]
# import sympy  # type: ignore[import]  File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 196, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 196, in <module>
#     import sympy  # type: ignore[import]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 151, in <module>
#     from . import _meta_registrations
#   File "/usr/local/lib/python3.9/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#         import sympy  # type: ignore[import]from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 107, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.9/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.9/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.9/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.9/dist-packages/torch/_guards.py", line 14, in <module>
#     import sympy  # type: ignore[import]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 73, in <module>
#     from .series import (Order, O, limit, Limit, gruntz, series, approximants,
#   File "/usr/local/lib/python3.9/dist-packages/sympy/series/__init__.py", line 10, in <module>
#     from .solvers import (solve, solve_linear_system, solve_linear_system_LU,
#       File "/usr/local/lib/python3.9/dist-packages/sympy/solvers/__init__.py", line 21, in <module>
#     from .geometry import (Point, Point2D, Point3D, Line, Ray, Segment, Line2D,
# from .geometry import (Point, Point2D, Point3D, Line, Ray, Segment, Line2D,  File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/__init__.py", line 13, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/__init__.py", line 13, in <module>
#     from .concrete import product, Product, summation, Sum
#   File "/usr/local/lib/python3.9/dist-packages/sympy/concrete/__init__.py", line 1, in <module>
#     import sympy  # type: ignore[import]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 73, in <module>
#         from .fourier import fourier_seriesfrom .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/series/fourier.py", line 3, in <module>
#           File "/usr/local/lib/python3.9/dist-packages/sympy/polys/__init__.py", line 117, in <module>
# import sympy  # type: ignore[import]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/__init__.py", line 73, in <module>
#     from .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/__init__.py", line 117, in <module>
#     from .ode import checkodesol, classify_ode, dsolve, \
#   File "/usr/local/lib/python3.9/dist-packages/sympy/solvers/ode/__init__.py", line 1, in <module>
# from .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/__init__.py", line 75, in <module>
#     from sympy.geometry.point import Point, Point2D, Point3D
#   File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/point.py", line 37, in <module>
#     from sympy.geometry.point import Point, Point2D, Point3D
#   File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/point.py", line 37, in <module>
#     from sympy.core.numbers import (oo, pi)
# from .products import product, Product
# KeyboardInterrupt
#   File "/usr/local/lib/python3.9/dist-packages/sympy/concrete/products.py", line 4, in <module>
#            WARNING  Sending process 1711 closing signal SIGINT        ]8;id=238713;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=122414;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#     from .partfrac import apart, apart_list, assemble_partfrac_list
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/partfrac.py", line 15, in <module>
#     from .partfrac import apart, apart_list, assemble_partfrac_list
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/partfrac.py", line 15, in <module>
#         from .ode import (allhints, checkinfsol, classify_ode,
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     from .entity import GeometryEntity
#   File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/entity.py", line 35, in <module>
#     from .entity import GeometryEntity
#   File "/usr/local/lib/python3.9/dist-packages/sympy/geometry/entity.py", line 35, in <module>
#       File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
# from .summations import Sum, summation, _dummy_with_inherited_properties_concrete
#   File "/usr/local/lib/python3.9/dist-packages/sympy/concrete/summations.py", line 26, in <module>
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1423, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1395, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1526, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1569, in _fill_cache
#         from sympy.sets.handlers.intersection import intersection_setsfrom sympy.sets.handlers.intersection import intersection_sets
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/sets/handlers/intersection.py", line 234, in <module>
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 935, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1079, in path_stats
#   File "<frozen importlib._bootstrap_external>", line 142, in _path_stat
# KeyboardInterrupt
#     def _(a, b):
#     from sympy.integrals.integrals import Integral  File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/dispatcher.py", line 148, in _
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/integrals/__init__.py", line 14, in <module>
#     self.add(types, func, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/dispatcher.py", line 219, in add
#     self.reorder(on_ambiguity=on_ambiguity)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/dispatcher.py", line 224, in reorder
# KeyboardInterrupt
#     self.ordering = ordering(self.funcs)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 62, in ordering
#     edges = [(a, b) for a in signatures for b in signatures if edge(a, b)]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 62, in <listcomp>
#     edges = [(a, b) for a in signatures for b in signatures if edge(a, b)]
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 48, in edge
#     from .transforms import (mellin_transform, inverse_mellin_transform,
#   File "/usr/local/lib/python3.9/dist-packages/sympy/integrals/transforms.py", line 2263, in <module>
#     if supercedes(a, b):
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 9, in supercedes
#     return len(a) == len(b) and all(map(issubclass, a, b))
# KeyboardInterrupt
# from .polyfuncs import (symmetrize, horner, interpolate,
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/polyfuncs.py", line 11, in <module>
#     class InverseFourierTransform(FourierTypeTransform):
#   File "/usr/local/lib/python3.9/dist-packages/sympy/core/function.py", line 165, in __init__
# def apart(f, x=None, full=False, **options):
#       File "/usr/local/lib/python3.9/dist-packages/sympy/utilities/decorator.py", line 77, in xthreaded
# def apart(f, x=None, full=False, **options):
#   File "/usr/local/lib/python3.9/dist-packages/sympy/utilities/decorator.py", line 77, in xthreaded
#         nargs = kwargs.pop('nargs', cls.__dict__.get('nargs', arity(cls)))
#   File "/usr/local/lib/python3.9/dist-packages/sympy/core/function.py", line 144, in arity
#     from sympy.polys.specialpolys import (
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/specialpolys.py", line 297, in <module>
# parameters = inspect.signature(eval_).parameters.items()
#   File "/usr/lib/python3.9/inspect.py", line 3113, in signature
#       File "/usr/local/lib/python3.9/dist-packages/sympy/utilities/decorator.py", line 14, in threaded_factory
#     return threaded_factory(func, False)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/utilities/decorator.py", line 14, in threaded_factory
#     from sympy.polys.rings import ringfrom sympy.matrices import MatrixBase
#   File "/usr/local/lib/python3.9/dist-packages/sympy/polys/rings.py", line 30, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/matrices/__init__.py", line 20, in <module>
# from sympy.matrices import MatrixBase
#   File "/usr/local/lib/python3.9/dist-packages/sympy/matrices/__init__.py", line 18, in <module>
#                 from .sparse import MutableSparseMatrixfrom sympy.printing.defaults import DefaultPrinting
#
# from .immutable import ImmutableDenseMatrix, ImmutableSparseMatrix  File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "/usr/local/lib/python3.9/dist-packages/sympy/printing/__init__.py", line 5, in <module>
#
#   File "/usr/local/lib/python3.9/dist-packages/sympy/matrices/immutable.py", line 182, in <module>
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#     from .latex import latex, print_latex, multiline_latex
#   File "/usr/local/lib/python3.9/dist-packages/sympy/printing/latex.py", line 18, in <module>
#   File "<frozen importlib._bootstrap_external>", line 978, in get_code
# return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#   File "/usr/lib/python3.9/inspect.py", line 2862, in from_callable
#   File "<frozen importlib._bootstrap_external>", line 647, in _compile_bytecode
# KeyboardInterrupt    def _eval_is_eq(lhs, rhs): # noqa:F811
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/core.py", line 70, in _
#         from sympy.tensor.array import NDimArray
#   File "/usr/local/lib/python3.9/dist-packages/sympy/tensor/__init__.py", line 4, in <module>
# dispatcher.add(types, func, on_ambiguity=on_ambiguity)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/dispatcher.py", line 219, in add
#     self.reorder(on_ambiguity=on_ambiguity)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/dispatcher.py", line 224, in reorder
#
# self.ordering = ordering(self.funcs)
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 67, in ordering
#     from .indexed import IndexedBase, Idx, Indexed
#   File "/usr/local/lib/python3.9/dist-packages/sympy/tensor/indexed.py", line 114, in <module>
#     edges = {k: [b for a, b in v] for k, v in edges.items()}
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 67, in <dictcomp>
#     edges = {k: [b for a, b in v] for k, v in edges.items()}
#   File "/usr/local/lib/python3.9/dist-packages/sympy/multipledispatch/conflict.py", line 67, in <listcomp>
#         from sympy.functions.special.tensor_functions import KroneckerDelta
#   File "/usr/local/lib/python3.9/dist-packages/sympy/functions/__init__.py", line 17, in <module>
# edges = {k: [b for a, b in v] for k, v in edges.items()}
# KeyboardInterrupt
#     from sympy.functions.elementary.trigonometric import (sin, cos, tan,
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
# return _signature_from_callable(obj, sigcls=cls,
#   File "/usr/lib/python3.9/inspect.py", line 2266, in _signature_from_callable
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
#     KeyboardInterrupt
# sig = _get_signature_of(obj.__func__)
#   File "/usr/lib/python3.9/inspect.py", line 2325, in _signature_from_callable
#     return _signature_from_function(sigcls, obj,           WARNING  Sending process 1712 closing signal SIGINT        ]8;id=138100;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=184807;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#
#   File "/usr/lib/python3.9/inspect.py", line 2241, in _signature_from_function
#     return cls(parameters,
#   File "/usr/lib/python3.9/inspect.py", line 2830, in __init__
#     params = OrderedDict((param.name, param) for param in parameters)
#   File "/usr/lib/python3.9/inspect.py", line 2830, in <genexpr>
#     params = OrderedDict((param.name, param) for param in parameters)
#   File "/usr/lib/python3.9/inspect.py", line 2548, in name
#     @property
# KeyboardInterrupt
#            WARNING  Sending process 1713 closing signal SIGINT        ]8;id=115194;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=901633;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#            WARNING  Sending process 1714 closing signal SIGINT        ]8;id=289681;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=584498;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#            WARNING  Sending process 1715 closing signal SIGINT        ]8;id=387930;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=427300;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#            WARNING  Sending process 1716 closing signal SIGINT        ]8;id=726806;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=68314;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#            WARNING  Sending process 1717 closing signal SIGINT        ]8;id=236249;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=938461;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
#            WARNING  Sending process 1718 closing signal SIGINT        ]8;id=262424;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py\api.py]8;;\:]8;id=669010;file:///usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py#698\698]8;;\
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/local/bin/accelerate:8 in <module>                                      │
# │                                                                              │
# │   5 from accelerate.commands.accelerate_cli import main                      │
# │   6 if __name__ == '__main__':                                               │
# │   7 │   sys.argv[0] = re.sub(r'(-script\.pyw|\.exe)?$', '', sys.argv[0])     │
# │ ❱ 8 │   sys.exit(main())                                                     │
# │   9                                                                          │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/accelerate/commands/accelerate_cli.py │
# │ :45 in main                                                                  │
# │                                                                              │
# │   42 │   │   exit(1)                                                         │
# │   43 │                                                                       │
# │   44 │   # Run                                                               │
# │ ❱ 45 │   args.func(args)                                                     │
# │   46                                                                         │
# │   47                                                                         │
# │   48 if __name__ == "__main__":                                              │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/accelerate/commands/launch.py:908 in  │
# │ launch_command                                                               │
# │                                                                              │
# │   905 │   │   if mp_from_config_flag:                                        │
# │   906 │   │   │   args.deepspeed_fields_from_accelerate_config.append("mixed │
# │   907 │   │   args.deepspeed_fields_from_accelerate_config = ",".join(args.d │
# │ ❱ 908 │   │   deepspeed_launcher(args)                                       │
# │   909 │   elif args.use_fsdp and not args.cpu:                               │
# │   910 │   │   multi_gpu_launcher(args)                                       │
# │   911 │   elif args.use_megatron_lm and not args.cpu:                        │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/accelerate/commands/launch.py:647 in  │
# │ deepspeed_launcher                                                           │
# │                                                                              │
# │   644 │   │   )                                                              │
# │   645 │   │   with patch_environment(**current_env):                         │
# │   646 │   │   │   try:                                                       │
# │ ❱ 647 │   │   │   │   distrib_run.run(args)                                  │
# │   648 │   │   │   except Exception:                                          │
# │   649 │   │   │   │   if is_rich_available() and debug:                      │
# │   650 │   │   │   │   │   console = get_console()                            │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/run.py:785 in run   │
# │                                                                              │
# │   782 │   │   )                                                              │
# │   783 │                                                                      │
# │   784 │   config, cmd, cmd_args = config_from_args(args)                     │
# │ ❱ 785 │   elastic_launch(                                                    │
# │   786 │   │   config=config,                                                 │
# │   787 │   │   entrypoint=cmd,                                                │
# │   788 │   )(*cmd_args)                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py:134 │
# │ in __call__                                                                  │
# │                                                                              │
# │   131 │   │   self._entrypoint = entrypoint                                  │
# │   132 │                                                                      │
# │   133 │   def __call__(self, *args):                                         │
# │ ❱ 134 │   │   return launch_agent(self._config, self._entrypoint, list(args) │
# │   135                                                                        │
# │   136                                                                        │
# │   137 def _get_entrypoint_name(                                              │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py:241 │
# │ in launch_agent                                                              │
# │                                                                              │
# │   238 │   try:                                                               │
# │   239 │   │   metrics.initialize_metrics(metrics.MetricsConfig(config.metric │
# │   240 │   │                                                                  │
# │ ❱ 241 │   │   result = agent.run()                                           │
# │   242 │   │   # records that agent.run() has succeeded NOT that workers have │
# │   243 │   │   events.record(agent.get_event_succeeded())                     │
# │   244                                                                        │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/metrics/api │
# │ .py:129 in wrapper                                                           │
# │                                                                              │
# │   126 │   │   │   key = _get_metric_name(f)                                  │
# │   127 │   │   │   try:                                                       │
# │   128 │   │   │   │   start = time.time()                                    │
# │ ❱ 129 │   │   │   │   result = f(*args, **kwargs)                            │
# │   130 │   │   │   │   put_metric(f"{key}.success", 1, group)                 │
# │   131 │   │   │   except Exception:                                          │
# │   132 │   │   │   │   put_metric(f"{key}.failure", 1, group)                 │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/serve │
# │ r/api.py:723 in run                                                          │
# │                                                                              │
# │   720 │   │   start_time = time.monotonic()                                  │
# │   721 │   │   shutdown_called: bool = False                                  │
# │   722 │   │   try:                                                           │
# │ ❱ 723 │   │   │   result = self._invoke_run(role)                            │
# │   724 │   │   │   self._total_execution_time = int(time.monotonic() - start_ │
# │   725 │   │   │   self._record_metrics(result)                               │
# │   726 │   │   │   self._record_worker_events(result)                         │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/serve │
# │ r/api.py:864 in _invoke_run                                                  │
# │                                                                              │
# │   861 │   │                                                                  │
# │   862 │   │   while True:                                                    │
# │   863 │   │   │   assert self._worker_group.state != WorkerState.INIT        │
# │ ❱ 864 │   │   │   time.sleep(monitor_interval)                               │
# │   865 │   │   │   run_result = self._monitor_workers(self._worker_group)     │
# │   866 │   │   │   state = run_result.state                                   │
# │   867 │   │   │   self._worker_group.state = state                           │
# │                                                                              │
# │ /usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiproces │
# │ sing/api.py:62 in _terminate_process_handler                                 │
# │                                                                              │
# │    59 │   be terminated.                                                     │
# │    60 │   """                                                                │
# │    61 │   sigval = signal.Signals(signum)                                    │
# │ ❱  62 │   raise SignalException(f"Process {os.getpid()} got signal: {sigval} │
# │    63                                                                        │
# │    64                                                                        │
# │    65 def _get_kill_signal() -> signal.Signals:                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# SignalException: Process 1632 got signal: 2
